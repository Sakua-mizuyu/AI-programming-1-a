# %%
2*(3+4)
# Out:
# 14

# %% [markdown]
# #初めてのノートバック
# ```
# **コード書きましょう**
# ```
# 123

# %%
x=5
print(x)
# Out:
# 5

# %%
'''
値を主力する
'''
print('First value:',1)
# Out:
# First value: 1

# %% [markdown]
# **`sort`の関数を呼び出す**
#
# 1. 以下のリストを作る
#
# ```
# Numbers=[4.3.2.1]
# ```
# 2. `sort()`の関数を使って、リストをソートする。
#
# 3. `print`を使って、主力する。

# %%
Numbers=[4,1,3,2]
Numbers.sort()
print(Numbers)
# Out:
# [1, 2, 3, 4]
